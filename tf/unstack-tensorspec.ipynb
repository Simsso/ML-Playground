# %%
import tensorflow as tf

# %%
spec = tf.TensorSpec(shape=(None, None, 10))

# %%
spec
# Out:
# TensorSpec(shape=(None, None, 10), dtype=tf.float32, name=None)

# %%
tf.unstack(spec, axis=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d40f39db309f> in <module>
# ----> 1 tf.unstack(spec, axis=2)
#
# /usr/local/anaconda3/envs/zalon_tf2/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/anaconda3/envs/zalon_tf2/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in unstack(value, num, axis, name)
#    1548   """
#    1549   if num is None:
# -> 1550     value = ops.convert_to_tensor(value)
#    1551     value_shape = value.get_shape()
#    1552     if value_shape.ndims is not None:
#
# ...

# %%
lst = []
for i in tf.range(tf.shape(spec)[2]):
    lst.append(spec[:, :, i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-c5467995a2a6> in <module>
#       1 lst = []
# ----> 2 for i in tf.range(tf.shape(spec)[2]):
#       3     lst.append(spec[:, :, i])
#
# /usr/local/anaconda3/envs/zalon_tf2/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/anaconda3/envs/zalon_tf2/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in shape_v2(input, out_type, name)
#     599     A `Tensor` of type `out_type`.
#     600   """
# --> 601   return shape(input, name, out_type)
#     602
#     603
#
# ...
